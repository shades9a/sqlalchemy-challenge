# %%
 # %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
 import numpy as np
import pandas as pd
import requests

# %%
 import datetime as dt

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
Base = automap_base()
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import Column, Integer, String, Float
session = Session(bind=engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c9598884f93b> in <module>
#       5 from sqlalchemy import create_engine, func
#       6 from sqlalchemy import Column, Integer, String, Float
# ----> 7 session = Session(bind=engine)
#
# NameError: name 'engine' is not defined

# %%
 engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
class Vacation(Base):
    __tablename__ = 'vacation_rain'
    id = Column(Integer, primary_key=True)
    name = Column(String(255))
    date = Column(String(255))
    prcp = Column(Integer, primary_key=True)
# Out:
# C:\Users\Edward\anaconda3\lib\site-packages\sqlalchemy\ext\declarative\clsregistry.py:125: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.Vacation, and will be replaced in the string-lookup table.
#   util.warn(

# %%
vacation_one = Vacation(name="Kamuela", date=5/16/2021, prcp=3.02)
vacation_two = Vacation(name="Kauai", date=5/16/2021, prcp=0.95)
vacation_three = Vacation(name="Oahu", date=5/16/2021, prcp=1.47)

# %%
Vacation.add(vacation_one)
Vacation.add(vacation_two)
Vacation.add(vacation_three)

session.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2efc681d7841> in <module>
# ----> 1 Vacation.add(vacation_one)
#       2 Vacation.add(vacation_two)
#       3 Vacation.add(vacation_three)
#       4
#       5 session.commit()
#
# NameError: name 'Vacation' is not defined

# %%
cities = ["Kamuela", "Kauai", "Oahu"]
percip = [31.4,13.77,15.09]

weather_dict = {
    "city": cities,
    "percipitation": percip
}
weather_data = pd.DataFrame(weather_dict)
weather_data

x_values = weather_data['city']
y_values = weather_data['percipitation']
plt.scatter(x_values,y_values)
plt.xlabel('city')
plt.ylabel('percipitation')
plt.show()

# %%
month = ["Jan", "Feb", "Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
percip = [2.9,2,1.4,1,1.2125,.8,.6,1.2,1.85,2.1,2.6,3]

weather_dict = {
    "Kamuela": month,
    "percipitation": percip
}
weather_data = pd.DataFrame(weather_dict)
weather_data

x_values = weather_data['Kamuela']
y_values = weather_data['percipitation']
plt.bar(x_values,y_values)
plt.xlabel('Kamuela')
plt.ylabel('percipitation')
plt.show()
